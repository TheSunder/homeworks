# %% [markdown]
# Вам необходимо провести базовый EDA выбранного набора данных.
#
# Требования к анализу:
#
# построить не менее 4 визуализаций различных видов;
# каждая визуализация должным образом оформлена и читается даже в отрыве от контекста;
# по каждой визуализации необходимо написать вывод (какую гипотезу на ее основе можно выдвинуть?).

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(
    'bestsellers with categories.csv')
plt.xlabel('Жанр книги')
plt.ylabel('Средняя цена')
plt.title('Соотношение жанра книги и средней цены')
df = data[['Genre', 'Price']]
df = df.groupby(['Genre']).mean()
df.unstack().plot(kind='bar')

#Делаем вывод, что художественная литература в среднем дешевле документальной(публицистической)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(
    'bestsellers with categories.csv')
data = data[['User Rating', 'Year']]
data = data[data.Year > 2014]
data = data.groupby(['Year']).mean()
plt.xlabel('Год')
plt.ylabel('Средняя оценка')
plt.title('График средней оценки в определенный год')

data.unstack().plot()

#Делаем вывод, что средняя оценка книг за 2019 год была значительно выше, чем в остальные

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(
    'bestsellers with categories.csv')
data = data[['Genre','Reviews']]

data = data.groupby(['Genre']).sum().sort_values(by='Reviews', ascending=False)
data.plot(kind='pie', y='Reviews', title = 'Сравнение кол-ва рецензий на жанр')
#Делаем вывод, что художественная литература набирает больше рецензий, чем публицистика

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(
    'bestsellers with categories.csv')
data = data[['Author','Name']]
data = data.groupby(['Author']).count().sort_values(by='Name', ascending=False).head(10)
plt.ylabel('Количество книг')
data.unstack().plot(kind='bar',title = 'топ 10 самых обсуждаемых авторов')

#Таким образом, был составлен топ 10 самых обсуждаемых авторов
